# %%
# %matplotlib inline
import UserData

# %%
data = UserData.data

# %% [markdown]
# # Marketing
# How did you hear about this event?

# %%
data.marketing()[:10].plot(kind = "bar")

# %% [markdown]
# # Students
# What is your major?

# %%
data.majors()[:8].plot(kind = "bar")

# %% [markdown]
# # Companies
# Which of the following companies have you heard of before?

# %%
companies = data.companies()[:]
companies.plot(kind = "bar")
